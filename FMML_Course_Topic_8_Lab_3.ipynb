# %% [markdown]
# <a href="https://colab.research.google.com/github/21JN1A4215/FMML-MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 14:31:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   175MB/s    in 0.4s
#
# 2024-03-25 14:31:08 (175 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14115  1711.04988v1  In spite of the growing computational power of...    cs
# 3213    1402.2333v1  Bi-linear feature learning models, like the ga...    cs
# 36004   0906.1842v1  Requirement volatility is an issue in software...    cs
# 1002   1507.00210v1  We introduce Natural Neural Networks, a novel ...  stat
# 22841  1708.05258v1  Choosing the best-performing optimizer(s) out ...  stat
# ...             ...                                                ...   ...
# 13161  1709.10250v2  We propose a top-down algorithm for multiple t...  stat
# 30143  1711.07828v3  The need for higher agricultural productivity ...    cs
# 17768  1802.08970v1  Generating plausible and fluent sentence with ...    cs
# 30932  1801.09360v1  Object tracking is one of the most challenging...    cs
# 21935  1612.00555v1  We aim to create a framework for transfer lear...  stat
#
#                                                    title  year  \
# 14115  Concurrent Pump Scheduling and Storage Level O...  2017
# 3213   Modeling sequential data using higher-order re...  2014
# 36004  Managing Requirement Volatility in an Ontology...  2009
# 1002                             Natural Neural Networks  2015
# 22841  Comprehensive Feature-Based Landscape Analysis...  2017
# ...                                                  ...   ...
# 13161  DAGGER: A sequential algorithm for FDR control...  2017
# 30143  A smartphone application to measure the qualit...  2017
# 17768  Incorporating Discriminator in Sentence Genera...  2018
# 30932  Comparative Study of ECO and CFNet Trackers in...  2018
# 21935  Transfer Learning via Latent Factor Modeling t...  2016
#
#                                                 keywords
# 14115  [computational, commodity, scheduling, distrib...
# 3213   [autoencoder, relationships, minimizing, recon...
# 36004  [requirement, volatility, engineering, applica...
# 1002   [introduce, algorithms, convergence, represent...
# 22841  [performing, portfolio, optimization, algorith...
# ...                                                  ...
# 13161  [algorithm, represent, hypotheses, hypotheses,...
# 30143  [agricultural, productivity, intensive, pestic...
# 17768  [generating, plausible, properties, challenge,...
# 30932  [challenging, significant, attention, research...
# 21935  [framework, dependence, structure, methodology...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14115    [computational, commodity, scheduling, distrib...
# 3213     [autoencoder, relationships, minimizing, recon...
# 36004    [requirement, volatility, engineering, applica...
# 1002     [introduce, algorithms, convergence, represent...
# 22841    [performing, portfolio, optimization, algorith...
#                                ...
# 10516    [supervised, ensembles, importance, ensembles,...
# 26855    [supervised, algorithm, cancerous, histopathol...
# 16948    [vocabulary, effective, generalization, vocabu...
# 28974    [demonstrate, robustness, reconstruction, appr...
# 26806    [discriminative, correlation, significantly, i...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8791 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c4ea349e-656f-4a79-a62e-c3695c3e3c57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4ea349e-656f-4a79-a62e-c3695c3e3c57")) {                    Plotly.newPlot(                        "c4ea349e-656f-4a79-a62e-c3695c3e3c57",                        [{"x":["distribution","algorithms","optimizing","performance","concurrent","generalized","commodity","predictable","technique","scheduling","optimized","algorithm","comparing","evolutionary","artificial","optimization","simultaneously","operation","challenge","computational","minimizing","objective","improvement","transformations","correctly","relational","predictive","autoencoder","sequential","propagating","structure","significant","prediction","reconstruction","evolution","relationships","replacing","introducing","increasing","formalized","consequently","information","ontologies","considerably","empowered","requirements","complexity","particular","applications","knowledge","international","management","requirement","framework","biomedical","telemedicine","interrelations","contributes","functionalities","incomplete","originates","engineering","hierarchies","difficult","reporting","laboratory","volatility","functional","understand","analyzing","conceptual","understanding","unsupervised","convergence","scalability","projected","conditioning","reparametrizations","implicitly","introduce","supervised","parameter","highlight","whitening","preserving","efficiently","efficient","reparametrization","representation","computation","especially","approaches","exploratory","considered","essential","platforms","collection","performing","independent","continuous","providing","techniques","ingredient","evaluations","interface","selection","properties","facilitates","comprehensive","advantageous","landscape","sophisticated","visualization","comprehensible","complicated","unfortunately","graphical","introduces","expensive","portfolio","constrained","landscapes","characterizing","underlying","numerical","effective","corresponding","functions","convenient","expressed","automatic","identification","expression","affective","additional","compositionality","dirichlet","expressions","discussion","classifying","differentiate","semantics","detection","investigate","clustering","paragraph","therefore","paragraphs","intensity","typically","allocation","hypothesis","incorporate","different","containing","encouraging","idiomatic","classified","classification","representatives","regularization","regularized","attraction","demonstrated","individual","maintained","parsimonious","interpretation","procedures","variables","ensembles","empirical","dimensional","visualize","predictor","attention","logarithmic","manifolds","corollary","measurements","grassmann","estimator","estimation","construct","estimated","developed","resultant","according","traditional","benchmark","coevolution","contribution","iteration","efficiency","constructs","considering","potential","subproblems","explicitly","theoretically"],"y":[199,625,46,948,12,62,5,9,249,18,44,840,70,55,131,325,116,41,165,281,47,156,154,41,43,27,56,29,76,10,355,260,222,95,58,67,18,58,101,5,43,671,23,26,2,60,245,260,431,334,14,37,39,552,20,1,2,11,3,33,3,49,17,156,7,8,3,33,67,59,22,152,158,125,30,16,12,0,27,363,231,100,25,0,46,170,404,1,355,140,124,414,10,146,61,34,71,75,119,103,84,381,3,60,22,153,214,20,71,5,11,29,26,1,38,30,66,76,64,4,67,7,19,113,99,234,143,236,17,33,164,99,48,8,116,9,15,41,19,31,8,97,351,153,140,5,126,2,26,119,24,58,62,757,56,22,2,40,546,2,100,43,5,105,117,7,4,55,44,111,11,164,156,11,14,179,22,16,2,49,1,31,204,71,48,203,11,111,184,233,3,70,55,170,23,71,149,4,60,43],"type":"bar"},{"x":["distribution","algorithms","optimizing","performance","conc ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Unsure</span> <span style=''>When</span> <span style=''>to</span> <span style=''>Stop</span> <span style=''>Ask</span> <span style=''>Your</span> <span style=''>Semantic</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>Neighbors</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>it</span> <span style=''>is</span> <span style=''>common</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>a</span> <span style=''>point</span> <span style=''>in</span> <span style=''>the</span> <span style=''>search</span> <span style=''>where</span> <span style=''>no</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363636);'>induction</span> <span style=''>seems</span> <span style=''>to</span> <span style=''>be</span> <span style=''>possible</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>data</span> <span style=''>If</span> <span style=''>the</span> <span style=''>search</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>continued</span> <span style=''>beyond</span> <span style=''>this</span> <span style=''>point</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increases</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Following</span> <span style=''>the</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developments</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inductive</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3937823834196892);'>stochastic</span> <span style=''>methods</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>studies</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>feasibility</span> <span style=''>of</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>gathered</span> <span style=''>from</span> <span style=''>the</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>to</span> <span style=''>decide</span> <span style=''>when</span> <span style=''>to</span> <span style=''>stop</span> <span style=''>the</span> <span style=''>search</span> <span style=''>Two</span> <span style=''>semantic</span> <span style=''>stopping</span> <span style=''>criteria</span> <span style=''>are</span> <span style=''>proposed</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experimentally</span> <span style=''>assessed</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Geometric</span> <span style=''>Semantic</span> <span style=''>Genetic</span> <span style='background-color:rgba(0, 255, 0, 0.4578313253012048);'>Programming</span> <span style=''>(GSGP)</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Semantic</span> <span style=''>Learning</span> <span style=''>Machine</span> <span style=''>(SLM)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>neural</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadrature</span> <span style=''>rules</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>misspecified</span> <span style=''>settings</span> <br/><br/><span style=''>Kernel</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadrature</span> <span style=''>rules</span> <span style=''>are</span> <span style=''>becoming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>as</span> <span style=''>they</span> <span style=''>achieve</span> <span style=''>super</span> <span style=''>sqrtn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternatives</span> <span style=''>to</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>settings</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrands</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>or</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrands</span> <span style=''>are</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>These</span> <span style=''>rules</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrand</span> <span style=''>has</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>degree</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothness</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrand</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>(RKHS)</span> <span style=''>However</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>can</span> <span style=''>be</span> <span style=''>violated</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>(eg</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrand</span> <span style=''>is</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style=''>function)</span> <span style=''>and</span> <span style=''>no</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.40229885057471265);'>Dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.5851851851851853);'>Covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <span style=''>into</span> <span style=''>Sparse</span> <span style=''>Markov</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Independence</span> <span style=''>Domains</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporating</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3113207547169812);'>combination</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>models</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3211169284467712);'>different</span> <span style=''>domains</span> <span style=''>We</span> <span style=''>posit</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>from</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3113207547169812);'>combination</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>Gaussian</span> <span style=''>Markov</span> <span style=''>model</span> <span style=''>(with</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>matrix)</span> <span style=''>and</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>model</span> <span style=''>(with</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.5851851851851853);'>covariance</span> <span style=''>matrix)</span> <span style=''>We</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>into</span> <span style=''>two</span> <span style=''>domains</span> <span style=''>viz</span> <span style=''>Markov</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>domains</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538461);'>identifiability</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>method</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.833333333333 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Proportion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiclass</span> <span style=''>Anomaly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rejection</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>fall</span> <span style=''>under</span> <span style=''>the</span> <span style=''>heading</span> <span style=''>of</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>wherein</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>of</span> <span style=''>training</span> <span style=''>and</span> <span style=''>testing</span> <span style=''>examples</span> <span style=''>differ</span> <span style=''>The</span> <span style=''>first</span> <span style=''>problem</span> <span style=''>studied</span> <span style=''>is</span> <span style=''>that</span> <span style=''>of</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proportion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proportions</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>testing</span> <span style=''>data</span> <span style=''>set</span> <span style=''>given</span> <span style=''>labeled</span> <span style=''>examples</span> <span style=''>of</span> <span style=''>each</span> <span style=''>class</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>on</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>the</span> <span style=''>novel</span> <span style=''>feature</span> <span style=''>that</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>data</span> <span style=''>from</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>classes</span> <span style=''>This</span> <span style=''>property</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>second</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>problem</span> <span style=''>namely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>anomaly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rejection</span> <span style=''>Here</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>design</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>that</span> <span style=''>has</span> <span style=''>the</span> <span style=''>option</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10304114490161002)
# 	challenging (0.10232558139534884)
# 	knowledge (0.11949910554561717)
# 	experimental (0.14168157423971378)
# 	information (0.24007155635062613)
# 	segmentation (0.08014311270125224)
# 	detection (0.12558139534883722)
# 	different (0.2708407871198569)
# 	convolutional (0.14561717352415027)
# 	recognition (0.1334525939177102)
#
# Some Statistics words are:
# 	algorithm (0.38952618453865334)
# 	stochastic (0.1341645885286783)
# 	variables (0.1371571072319202)
# 	statistical (0.1596009975062344)
# 	estimation (0.17955112219451372)
# 	theoretical (0.16159600997506235)
# 	distribution (0.19251870324189527)
# 	regression (0.16658354114713217)
# 	dimensional (0.1825436408977556)
# 	inference (0.20199501246882792)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="273120c4-12d6-4f73-b936-c2bbc913cc0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("273120c4-12d6-4f73-b936-c2bbc913cc0e")) {                    Plotly.newPlot(                        "273120c4-12d6-4f73-b936-c2bbc913cc0e",                        [{"x":["distribution","algorithms","optimizing","performance","concurrent","generalized","commodity","predictable","technique","scheduling","optimized","algorithm","comparing","evolutionary","artificial","optimization","simultaneously","operation","challenge","computational","minimizing","objective","improvement","transformations","correctly","relational","predictive","autoencoder","sequential","propagating","structure","significant","prediction","reconstruction","evolution","relationships","replacing","introducing","increasing","formalized","consequently","information","ontologies","considerably","empowered","requirements","complexity","particular","applications","knowledge","international","management","requirement","framework","biomedical","telemedicine","interrelations","contributes","functionalities","incomplete","originates","engineering","hierarchies","difficult","reporting","laboratory","volatility","functional","understand","analyzing","conceptual","understanding","unsupervised","convergence","scalability","projected","conditioning","reparametrizations","implicitly","introduce","supervised","parameter","highlight","whitening","preserving","efficiently","efficient","reparametrization","representation","computation","especially","approaches","exploratory","considered","essential","platforms","collection","performing","independent","continuous","providing","techniques","ingredient","evaluations","interface","selection","properties","facilitates","comprehensive","advantageous","landscape","sophisticated","visualization","comprehensible","complicated","unfortunately","graphical","introduces","expensive","portfolio","constrained","landscapes","characterizing","underlying","numerical","effective","corresponding","functions","convenient","expressed","automatic","identification","expression","affective","additional","compositionality","dirichlet","expressions","discussion","classifying","differentiate","semantics","detection","investigate","clustering","paragraph","therefore","paragraphs","intensity","typically","allocation","hypothesis","incorporate","different","containing","encouraging","idiomatic","classified","classification","representatives","regularization","regularized","attraction","demonstrated","individual","maintained","parsimonious","interpretation","procedures","variables","ensembles","empirical","dimensional","visualize","predictor","attention","logarithmic","manifolds","corollary","measurements","grassmann","estimator","estimation","construct","estimated","developed","resultant","according","traditional","benchmark","coevolution","contribution","iteration","efficiency","constructs","considering","potential","subproblems","explicitly","theoretically","heuristic","combining","strategies","outperforms","subproblem","experimental","adaptively","excellent","allocating","characteristics","differential","cooperative","demonstrate","mathematical","competitive","significantly","generalization","formulated","reproducibility","synthetic","formulation","effectiveness","exploiting","including","intuitive","theoretical","informatics","regularizer","approximating","interpretations","suboptimal","successfully","comparison","reconstructed","proximity","arbitrary","respectively","amplification","eigenmaps","observation","nonlinear","neighborhood","reconstruct","consequence","situation","application","practitioner","combinatorial","customized","configurable","parameters","desc ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reparametrizations
# 	whitening
# 	penalizations
# 	frequentist
# 	changepoints
# 	renewable
# 	nonstationarity
# 	forecasted
# 	unplanned
# 	censoring
# 	noiseless
# 	activates
# 	thermostats
# 	linearnonlinear
# 	integrands
# 	quadrature
# 	coarsening
# 	exoplanet
# 	confounders
# 	inhibited
# Some words which never appear in Statistics papers:
# 	concurrent
# 	empowered
# 	interrelations
# 	functionalities
# 	affective
# 	paragraphs
# 	coevolution
# 	configurable
# 	satisfiability
# 	propositional
# 	extendable
# 	mechanically
# 	grayscale
# 	subjectivity
# 	prerequisite
# 	quickbird
# 	homography
# 	ontological
# 	reconfigurable
# 	contracts

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0761658668635414e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
